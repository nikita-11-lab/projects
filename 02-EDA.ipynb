# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('cleaned_data.csv')

# %%
df
# Out:
#                   name   company  year   Price  kms_driven fuel_type
# 0          Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1           Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2            Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Figo      Ford  2012  175000       41000    Diesel
# ..                 ...       ...   ...     ...         ...       ...
# 715        Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 716          Indica V2      Tata  2009  110000       30000    Diesel
# 717      Corolla Altis    Toyota  2009  300000      132000    Petrol
# 718            Zest XM      Tata  2018  260000       27000    Diesel
# 719          Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [720 rows x 6 columns]

# %%
data=df['company'].value_counts()

# %%
data
# Out:
# company
# Maruti        199
# Hyundai       129
# Mahindra       78
# Tata           61
# Honda          51
# Toyota         34
# Chevrolet      33
# Ford           26
# Renault        26
# Volkswagen     17
# Skoda          10
# Audi           10
# BMW             8
# Datsun          6
# Nissan          6
# Mercedes        6
# Mitsubishi      5
# Hindustan       3
# Fiat            3
# Mini            2
# Force           2
# Jaguar          2
# Land            1
# Jeep            1
# Volvo           1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(data.index,data.values)
plt.title('companywise vehicle count')
plt.xlabel('company')
plt.ylabel('vehicle')
plt.xticks(rotation=90)
for x,y in zip(data.index,data.values):
    plt.text(x,y,y,ha='center',va='bottom',fontsize=6)
plt.show()

# %%
#yearwise vehicle count
ax=df['year'].value_counts().sort_index().plot(kind='bar')
ax.bar_label(ax.containers[0],fontsize=6)
plt.title('yearwise vehicle count')
plt.xlabel('year')
plt.ylabel('vehicle')
plt.show()

# %%
df['fuel_type'].value_counts().plot(kind='pie',autopct='%1.1f%%',figsize=(5,5),startangle=90)
plt.title('fueltype wise count of vehicle')
plt.xlabel('fuel_type')
plt.ylabel('vehicle')
plt.show()

# %%
min_kms=df['kms_driven'].min()
max_kms=df['kms_driven'].max()
mean_kms=df['kms_driven'].mean()
print("min kms:",min_kms)
print("max kms:",max_kms)
print("mean kms:",mean_kms)
# Out:
# min kms: 0
# max kms: 400000
# mean kms: 46787.39722222222

# %%
#kms_driven wise company
sns.swarmplot(x='company',y='kms_driven',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
#company wise price
sns.swarmplot(x='company',y='Price',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        720 non-null    str
#  1   company     720 non-null    str
#  2   year        720 non-null    int64
#  3   Price       720 non-null    int64
#  4   kms_driven  720 non-null    int64
#  5   fuel_type   720 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 33.9 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        720 non-null    str
#  1   company     720 non-null    str
#  2   year        720 non-null    int64
#  3   Price       720 non-null    int64
#  4   kms_driven  720 non-null    int64
#  5   fuel_type   720 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 33.9 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        720 non-null    str
#  1   company     720 non-null    str
#  2   year        720 non-null    int64
#  3   Price       720 non-null    int64
#  4   kms_driven  720 non-null    int64
#  5   fuel_type   720 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 33.9 KB

# %%
df = df[(df['kms_driven'] >=1000) & (df['kms_driven']<200000)]
df=df[(df['Price']>=70000) & (df['Price'] <= 2000000)]
df=df[df['fuel_type']!='LPG']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 93 entries, 12 to 712
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        93 non-null     str
#  1   company     93 non-null     str
#  2   year        93 non-null     int64
#  3   Price       93 non-null     int64
#  4   kms_driven  93 non-null     int64
#  5   fuel_type   93 non-null     str
# dtypes: int64(3), str(3)
# memory usage: 5.1 KB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 658 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        658 non-null    str
#  1   company     658 non-null    str
#  2   year        658 non-null    int64
#  3   Price       658 non-null    int64
#  4   kms_driven  658 non-null    int64
#  5   fuel_type   658 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 36.0 KB

# %%
df.to_csv('final_data.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 658 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        658 non-null    str
#  1   company     658 non-null    str
#  2   year        658 non-null    int64
#  3   Price       658 non-null    int64
#  4   kms_driven  658 non-null    int64
#  5   fuel_type   658 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 36.0 KB
